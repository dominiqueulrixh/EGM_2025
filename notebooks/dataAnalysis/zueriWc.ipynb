# %%
#Fixe WC's
import geopandas as gpd

# Datei laden
wcFix = gpd.read_file("/Users/dominiqueulrich/PycharmProjects/EGM_2025/data/Rohdaten/zueri_wc_geojson/data/stzh.poi_zueriwc_view.json")

# Datentypen prüfen
print("Datentypen:")
print(wcFix.dtypes)

# Nullwerte zählen
print("\nNullwerte pro Spalte:")
print(wcFix.isnull().sum().sort_values(ascending=False))

# Shape & Vorschau
print("\n Form:", wcFix.shape)
print("\n Erste 5 Zeilen:")
print(wcFix.head())

# Anzahl eindeutiger Werte je Spalte
print("\n Eindeutige Werte pro Spalte:")
print(wcFix.nunique().sort_values(ascending=False))

# Duplikate prüfen
print("\n️ Doppelte Zeilen:", wcFix.duplicated().sum())
print(" Doppelte Geometrien:", wcFix.geometry.duplicated().sum())

# Spalten mit nur einem Wert?
print("\n Spalten mit nur einem Wert:")
print(wcFix.columns[wcFix.nunique() <= 1])

# Beispiel: Welche wcFix-Typen gibt es?
print("\n Typenübersicht:")
print(wcFix["typ"].value_counts())
# Out:
# Datentypen:
# adr_inter                        object
# adresse                          object
# adrzus_int                       object
# behindertenparkplatz             object
# bemerkung                        object
# ccmail                           object
# da                               object
# datum                            object
# datum_cms                        object
# dep                              object
# editor                           object
# erforderlichedokumente           object
# fax                              object
# hausnummer                       object
# hindernisfreiheit                object
# infrastruktur                    object
# isbetriebsferien_gebaeude        object
# isbetriebsferien_schalter        object
# kategorie                        object
# mail                             object
# name                             object
# namenzus                         object
# objectid                         object
# oeffnungszeiten_gebaeude_di      object
# oeffnungszeiten_gebaeude_do      object
# oeffnungszeiten_gebaeude_fr      object
# oeffnungszeiten_gebaeude_mi      object
# oeffnungszeiten_gebaeude_mo      object
# oeffnungszeiten_gebaeude_sa      object
# oeffnungszeiten_gebaeude_so      object
# oeffnungszeiten_schalter_di      object
# oeffnungszeiten_schalter_do      object
# oeffnungszeiten_schalter_fr      object
# oeffnungszeiten_schalter_mi      object
# oeffnungszeiten_schalter_mo      object
# oeffnungszeiten_schalter_sa      object
# oeffnungszeiten_schalter_so      object
# ort                              object
# plz                              object
# poi_id                           object
# postadresse                      object
# publish_internet                 object
# strasse                          object
# suchen                           object
# tel                              object
# tel2                             object
# www                              object
# zahlungsmittel_internet          object
# zahlungsmittel_schalter          object
# zahlungsmittel_telefon           object
# zvv_label                        object
# zvv_link                         object
# typ                              object
# kreis                             int32
# kommentar                        object
# gebuehren                        object
# oeffnungsz                       object
# standort                         object
# geometry                       geometry
# dtype: object
#
# Nullwerte pro Spalte:
# adr_inter                      25
# adrzus_int                     25
# ccmail                         25
# tel2                           25
# datum_cms                      25
# namenzus                       25
# erforderlichedokumente         25
# fax                            25
# postadresse                    25
# behindertenparkplatz           24
# bemerkung                      23
# strasse                         1
# hausnummer                      1
# tel                             0
# suchen                          0
# poi_id                          0
# publish_internet                0
# plz                             0
# ort                             0
# oeffnungszeiten_schalter_so     0
# www                             0
# zvv_label                       0
# zahlungsmittel_internet         0
# zahlungsmittel_schalter         0
# zahlungsmittel_telefon          0
# oeffnungszeiten_schalter_mo     0
# zvv_link                        0
# typ                             0
# kreis                           0
# kommentar                       0
# gebuehren                       0
# oeffnungsz                      0
# standort                        0
# oeffnungszeiten_schalter_sa     0
# oeffnungszeiten_gebaeude_so     0
# oeffnungszeiten_schalter_mi     0
# oeffnungszeiten_schalter_fr     0
# da                              0
# datum                           0
# dep                             0
# editor                          0
# hindernisfreiheit               0
# infrastruktur                   0
# isbetriebsferien_gebaeude       0
# isbetriebsferien_schalter       0
# kategorie                       0
# mail                            0
# name                            0
# objectid                        0
# oeffnungszeiten_gebaeude_di     0
# oeffnungszeiten_gebaeude_do     0
# oeffnungszeiten_gebaeude_fr     0
# oeffnungszeiten_gebaeude_mi     0
# oeffnungszeiten_gebaeude_mo     0
# oeffnungszeiten_gebaeude_sa     0
# adresse                         0
# oeffnungszeiten_schalter_di     0
# oeffnungszeiten_schalter_do     0
# geometry                        0
# dtype: int64
#
#  Form: (25, 59)
#
#  Erste 5 Zeilen:
#   adr_inter                 adresse adrzus_int behindertenparkplatz bemerkung  \
# 0      None         Schlossgasse 21       None                 None      None
# 1      None  Friesenbergstrasse 130       None                 None      None
# 2      None       Militärstrasse 45       None                 None      None
# 3      None         Seestrasse 495b       None                 None      None
# 4      None      Zeughausstrasse 56       None                 None      None
#
#   ccmail                             da         datum datum_cms  \
# 0   None  Umwelt- und Gesundheitsschutz  202412161145      None
# 1   None  Umwelt- und Gesundheitsschutz  202412161145      None
# 2   None  Umwelt- und Gesundheitsschutz  202412161145      None
# 3   None  Umwelt- und Gesundheitsschutz  202412161145      None
# 4   None  Umwelt- und Gesundheitsschutz  202412161145      None
#
#                                         dep  ... zahlungsmittel_telefon  \
# 0  Gesundheits- und Umweltdepartement (GUD)  ...             NULL;NULL;
# 1  Gesundheits- und Umweltdepartement (GUD)  ...             NULL;NULL;
# 2  Gesundheits- und Umweltdepartement (GUD)  ...             NULL;NULL;
# 3  Gesundheits- und Umweltdepartement (GUD)  ...             NULL;NULL;
# 4  Gesundheits- und Umweltdepartement (GUD)  ...             NULL;NULL;
#
#                 zvv_label                                           zvv_link  \
# 0         Schlossgasse 21  https://www.zvv.ch/de/fahrplan-und-information...
# 1  Friesenbergstrasse 130  https://www.zvv.ch/de/fahrplan-und-information...
# 2       Militärstrasse 45  https://www.zvv.ch/de/fahrplan-und-information...
# 3         Seestrasse 495b  https://www.zvv.ch/de/fahrplan-und-information...
# 4      Zeughausstrasse 56  https://www.zvv.ch/de/fahrplan-und-information...
#
#                      typ kreis  \
# 0  nicht rollstuhlgängig     3
# 1  nicht rollstuhlgängig     3
# 2                Pissoir     4
# 3  nicht rollstuhlgängig     2
# 4                Pissoir     4
#
#                                            kommentar      gebuehren  \
# 0                                 Multifunktions-WC.   Gebührenfrei
# 1  Multifunktions-WC beim neu gestalteten Spielpl...  Gebührenfrei.
# 2                                Zurzeit geschlossen   Gebührenfrei
# 3  2 Multifunktions-WCs. Für RollstuhlfahrerInnen...   Gebührenfrei
# 4                               Zurzeit geschlossen.   Gebührenfrei
#
#   oeffnungsz                                         standort  \
# 0       24 h              Schlossgasse 21 / Ecke Steinstrasse
# 1       24 h      Friesenbergstrasse 130 / Ecke Wasserschöpfi
# 2       24 h                                   beim Zeughaus.
# 3        24h  Seestr. 495b, bei der Zufahrt zum Rest. Seerose
# 4       24 h         Zeughausstr. 56 / Einmündung Rotwandstr.
#
#                    geometry
# 0   POINT (8.51911 47.3686)
# 1   POINT (8.5084 47.36506)
# 2  POINT (8.53152 47.37742)
# 3  POINT (8.53959 47.33806)
# 4  POINT (8.52974 47.37624)
#
# [5 rows x 59 columns]
#
#  Eindeutige Werte pro Spalte:
# geometry                       25
# zvv_link                       25
# objectid                       25
# poi_id                         25
# name                           25
# adresse                        25
# zvv_label                      25
# standort                       25
# hausnummer                     23
# kommentar                      22
# strasse                        21
# plz                            13
# infrastruktur                  13
# kreis                          10
# oeffnungsz                      9
# gebuehren                       5
# datum                           3
# publish_internet                2
# editor                          2
# bemerkung                       2
# typ                             2
# oeffnungszeiten_schalter_sa     1
# oeffnungszeiten_schalter_so     1
# ort                             1
# zahlungsmittel_schalter         1
# suchen                          1
# tel                             1
# www                             1
# zahlungsmittel_internet         1
# oeffnungszeiten_schalter_mi     1
# zahlungsmittel_telefon          1
# oeffnungszeiten_schalter_mo     1
# oeffnungszeiten_gebaeude_so     1
# oeffnungszeiten_schalter_fr     1
# mail                            1
# behindertenparkplatz            1
# da                              1
# dep                             1
# hindernisfreiheit               1
# isbetriebsferien_gebaeude       1
# isbetriebsferien_schalter       1
# oeffnungszeiten_schalter_do     1
# kategorie                       1
# oeffnungszeiten_gebaeude_di     1
# oeffnungszeiten_gebaeude_do     1
# oeffnungszeiten_gebaeude_fr     1
# oeffnungszeiten_gebaeude_mi     1
# oeffnungszeiten_gebaeude_mo     1
# oeffnungszeiten_gebaeude_sa     1
# oeffnungszeiten_schalter_di     1
# namenzus                        0
# tel2                            0
# postadresse                     0
# fax                             0
# erforderlichedokumente          0
# datum_cms                       0
# ccmail                          0
# adrzus_int                      0
# adr_inter                       0
# dtype: int64
#
# ️ Doppelte Zeilen: 0
#  Doppelte Geometrien: 0
#
#  Spalten mit nur einem Wert:
# Index(['adr_inter', 'adrzus_int', 'behindertenparkplatz', 'ccmail', 'da',
#        'datum_cms', 'dep', 'erforderlichedokumente', 'fax',
#        'hindernisfreiheit', 'isbetriebsferien_gebaeude',
#        'isbetriebsferien_schalter', 'kategorie', 'mail', 'namenzus',
#        'oeffnungszeiten_gebaeude_di', 'oeffnungszeiten_gebaeude_do',
#        'oeffnungszeiten_gebaeude_fr', 'oeffnungszeiten_gebaeude_mi',
#        'oeffnungszeiten_gebaeude_mo', 'oeffnungszeiten_gebaeude_sa',
#        'oeffnungszeiten_gebaeude_so', 'oeffnungszeiten_schalter_di',
#        'oeffnungszeiten_schalter_do', 'oeffnungszeiten_schalter_fr',
#        'oeffnungszeiten_schalter_mi', 'oeffnungszeiten_schalter_mo',
#        'oeffnungszeiten_schalter_sa', 'oeffnungszeiten_schalter_so', 'ort',
#        'postadresse', 'suchen', 'tel', 'tel2', 'www',
#        'zahlungsmittel_internet', 'zahlungsmittel_schalter',
#        'zahlungsmittel_telefon'],
#       dtype='object')
#
#  Typenübersicht:
# typ
# nicht rollstuhlgängig    21
# Pissoir                   4
# Name: count, dtype: int64

# %% [markdown]
# .### 📝 Datenprüfung: Fixe öffentliche Toiletten Zürich (ZüriWC)
#
# Die erste Prüfung des Datensatzes zeigt, dass 25 öffentliche Toilettenstandorte in der Stadt Zürich erfasst wurden. Insgesamt sind 59 Attribute pro Eintrag vorhanden.
#
# **Datenstruktur:**
# - Alle Einträge enthalten gültige Geometrien (Punktdaten).
# - Die Daten liegen überwiegend im `object`-Format vor, einschliesslich einiger Spalten, die potenziell als kategorisch oder numerisch sinnvoll wären (z.B. `kreis`, `gebuehren`).
#
# **Nullwerte:**
# - Mehrere Spalten enthalten fast ausschliesslich fehlende Werte, darunter `adr_inter`, `adrzus_int`, `datum_cms`, `fax`, `tel2` u.a.
# - Diese Felder erscheinen redundant oder irrelevant für unsere Analyse und können entfernt werden.
#
# **Spalten mit nur einem (oder keinem) eindeutigen Wert:**
# - 37 Spalten zeigen nur eine Ausprägung oder sind komplett leer.
# - Diese Felder tragen keine differenzierende Information bei und können für eine reduzierte, analytische Version des Datensatzes ausgeschlossen werden.
#
# **Duplikate:**
# - Es existieren keine doppelten Zeilen oder Geometrien → gute Datenqualität hinsichtlich Eindeutigkeit.
#
# **Erste Einblicke:**
# - Es existieren nur zwei Typen von Toiletten: `nicht rollstuhlgängig` (21x) und `Pissoir` (4x).
# - Alle Einträge sind auf 10 verschiedene Stadt-Kreise (`kreis`) verteilt.
# - Das Attribut `gebuehren` weist fünf verschiedene Textvarianten auf (z.B. „Gebührenfrei“, „Gebührenfrei.“) → Vereinheitlichung notwendig.
#
# **Fazit:**
# Für die weitere Analyse empfiehlt sich eine Reduktion des Datensatzes auf relevante Spalten wie Name, Typ, Gebühren, Öffnungszeiten, Standort (Koordinaten & Adresse) und Kreis. Optional kann durch den Import weiterer Dateien (z.B. `mobil_view.json`) eine Erweiterung auf mobile oder temporäre Toilettenstandorte erfolgen.

# %%
#cleaned ds
import geopandas as gpd

# Relevante Spalten auswählen
spalten_relevant = [
    "geometry", "zvv_link", "objectid", "poi_id", "name",
    "adresse", "zvv_label", "standort", "hausnummer",
    "kommentar", "strasse", "plz", "infrastruktur", "kreis"
]

# Bereinigten DataFrame erzeugen
wc_cleaned = wcFix[spalten_relevant].copy()

# "kreis" zu Integer (optional)
wc_cleaned["kreis"] = wc_cleaned["kreis"].astype(int)

# Vorschau
print(wc_cleaned.head())

# Abspeichern
wc_cleaned.to_file("../", driver="GeoJSON")
# Out:
#                    geometry  \
# 0   POINT (8.51911 47.3686)
# 1   POINT (8.5084 47.36506)
# 2  POINT (8.53152 47.37742)
# 3  POINT (8.53959 47.33806)
# 4  POINT (8.52974 47.37624)
#
#                                             zvv_link objectid poi_id  \
# 0  https://www.zvv.ch/de/fahrplan-und-information...     7119  wc030
# 1  https://www.zvv.ch/de/fahrplan-und-information...     7120  wc034
# 2  https://www.zvv.ch/de/fahrplan-und-information...     7238  wc041
# 3  https://www.zvv.ch/de/fahrplan-und-information...     7905  wc018
# 4  https://www.zvv.ch/de/fahrplan-und-information...     8017  wc045
#
#                                         name                 adresse  \
# 0        Kollerwiese (nicht rollstuhlgängig)         Schlossgasse 21
# 1      Wasserschöpfi (nicht rollstuhlgängig)  Friesenbergstrasse 130
# 2                   Militärstrasse (Pissoir)       Militärstrasse 45
# 3  Hafen Wollishofen (nicht rollstuhlgängig)         Seestrasse 495b
# 4                  Zeughausstrasse (Pissoir)      Zeughausstrasse 56
#
#                 zvv_label                                         standort  \
# 0         Schlossgasse 21              Schlossgasse 21 / Ecke Steinstrasse
# 1  Friesenbergstrasse 130      Friesenbergstrasse 130 / Ecke Wasserschöpfi
# 2       Militärstrasse 45                                   beim Zeughaus.
# 3         Seestrasse 495b  Seestr. 495b, bei der Zufahrt zum Rest. Seerose
# 4      Zeughausstrasse 56         Zeughausstr. 56 / Einmündung Rotwandstr.
#
#   hausnummer                                          kommentar  \
# 0         21                                 Multifunktions-WC.
# 1        130  Multifunktions-WC beim neu gestalteten Spielpl...
# 2         45                                Zurzeit geschlossen
# 3       495b  2 Multifunktions-WCs. Für RollstuhlfahrerInnen...
# 4         56                               Zurzeit geschlossen.
#
#               strasse   plz                      infrastruktur  kreis
# 0        Schlossgasse  8003        ;Geöffnet 24h. Gebührenfrei      3
# 1  Friesenbergstrasse  8055        ;Geöffnet 24h. Gebührenfrei      3
# 2      Militärstrasse  8004  ;Pissoir für Männer. Gebührenfrei      4
# 3          Seestrasse  8002        ;Geöffnet 24h. Gebührenfrei      2
# 4     Zeughausstrasse  8004  ;Pissoir für Männer. Gebührenfrei      4
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File pyogrio/_io.pyx:1947, in pyogrio._io.ogr_create()
#
# File pyogrio/_err.pyx:183, in pyogrio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Failed to create GeoJSON datasource: ../../data/Cleaned/zueriWc_cleaned.geojson: ../../data/Cleaned/zueriWc_cleaned.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DataSourceError                           Traceback (most recent call last)
# Cell In[15], line 21
#      18 print(wc_cleaned.head())
#      20 # Abspeichern
# ---> 21 wc_cleaned.to_file("../../data/Cleaned/zueriWc_cleaned.geojson", driver="GeoJSON")
#
# File ~/PycharmProjects/EGM_2025/.venv/lib/python3.12/site-packages/geopandas/geodataframe.py:1536, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1441 """Write the ``GeoDataFrame`` to a file.
#    1442
#    1443 By default, an ESRI shapefile is written, but any OGR data source
#    (...)   1532
#    1533 """
#    1534 from geopandas.io.file import _to_file
# -> 1536 _to_file(self, filename, driver, schema, index, **kwargs)
#
# File ~/PycharmProjects/EGM_2025/.venv/lib/python3.12/site-packages/geopandas/io/file.py:686, in _to_file(df, filename, driver, schema, index, mode, crs, engine, metadata, **kwargs)
#     683     raise ValueError(f"'mode' should be one of 'w' or 'a', got '{mode}' instead")
#     685 if engine == "pyogrio":
# --> 686     _to_file_pyogrio(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#     687 elif engine == "fiona":
#     688     _to_file_fiona(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#
# File ~/PycharmProjects/EGM_2025/.venv/lib/python3.12/site-packages/geopandas/io/file.py:748, in _to_file_pyogrio(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#     745 if not df.columns.is_unique:
#     746     raise ValueError("GeoDataFrame cannot contain duplicated column names.")
# --> 748 pyogrio.write_dataframe(df, filename, driver=driver, metadata=metadata, **kwargs)
#
# File ~/PycharmProjects/EGM_2025/.venv/lib/python3.12/site-packages/pyogrio/geopandas.py:662, in write_dataframe(df, path, layer, driver, encoding, geometry_type, promote_to_multi, nan_as_null, append, use_arrow, dataset_metadata, layer_metadata, metadata, dataset_options, layer_options, **kwargs)
#     659 if geometry_column is not None:
#     660     geometry = to_wkb(geometry.values)
# --> 662 write(
#     663     path,
#     664     layer=layer,
#     665     driver=driver,
#     666     geometry=geometry,
#     667     field_data=field_data,
#     668     field_mask=field_mask,
#     669     fields=fields,
#     670     crs=crs,
#     671     geometry_type=geometry_type,
#     672     encoding=encoding,
#     673     promote_to_multi=promote_to_multi,
#     674     nan_as_null=nan_as_null,
#     675     append=append,
#     676     dataset_metadata=dataset_metadata,
#     677     layer_metadata=layer_metadata,
#     678     metadata=metadata,
#     679     dataset_options=dataset_options,
#     680     layer_options=layer_options,
#     681     gdal_tz_offsets=gdal_tz_offsets,
#     682     **kwargs,
#     683 )
#
# File ~/PycharmProjects/EGM_2025/.venv/lib/python3.12/site-packages/pyogrio/raw.py:723, in write(path, geometry, field_data, fields, field_mask, layer, driver, geometry_type, crs, encoding, promote_to_multi, nan_as_null, append, dataset_metadata, layer_metadata, metadata, dataset_options, layer_options, gdal_tz_offsets, **kwargs)
#     718 # preprocess kwargs and split in dataset and layer creation options
#     719 dataset_kwargs, layer_kwargs = _preprocess_options_kwargs(
#     720     driver, dataset_options, layer_options, kwargs
#     721 )
# --> 723 ogr_write(
#     724     path,
#     725     layer=layer,
#     726     driver=driver,
#     727     geometry=geometry,
#     728     geometry_type=geometry_type,
#     729     field_data=field_data,
#     730     field_mask=field_mask,
#     731     fields=fields,
#     732     crs=crs,
#     733     encoding=encoding,
#     734     promote_to_multi=promote_to_multi,
#     735     nan_as_null=nan_as_null,
#     736     append=append,
#     737     dataset_metadata=dataset_metadata,
#     738     layer_metadata=layer_metadata,
#     739     dataset_kwargs=dataset_kwargs,
#     740     layer_kwargs=layer_kwargs,
#     741     gdal_tz_offsets=gdal_tz_offsets,
#     742 )
#
# File pyogrio/_io.pyx:2307, in pyogrio._io.ogr_write()
#
# File pyogrio/_io.pyx:2135, in pyogrio._io.create_ogr_dataset_layer()
#
# File pyogrio/_io.pyx:1956, in pyogrio._io.ogr_create()
#
# DataSourceError: Failed to create GeoJSON datasource: ../../data/Cleaned/zueriWc_cleaned.geojson: ../../data/Cleaned/zueriWc_cleaned.geojson: No such file or directory

# %%
#Mobile WC's
import geopandas as gpd

# Datei laden
wcMobil = gpd.read_file("/Users/dominiqueulrich/PycharmProjects/EGM_2025/data/Rohdaten/zueri_wc_geojson/data/stzh.poi_zueriwc_mobil_view.json")

# Datentypen prüfen
print("Datentypen:")
print(wcMobil.dtypes)

# Nullwerte zählen
print("\nNullwerte pro Spalte:")
print(wcMobil.isnull().sum().sort_values(ascending=False))

# Shape & Vorschau
print("\n Form:", wcMobil.shape)
print("\n Erste 5 Zeilen:")
print(wcMobil.head())

# Anzahl eindeutiger Werte je Spalte
print("\n Eindeutige Werte pro Spalte:")
print(wcMobil.nunique().sort_values(ascending=False))

# Duplikate prüfen
print("\n️ Doppelte Zeilen:", wcMobil.duplicated().sum())
print(" Doppelte Geometrien:", wcMobil.geometry.duplicated().sum())

# Spalten mit nur einem Wert?
print("\n Spalten mit nur einem Wert:")
print(wcMobil.columns[wcMobil.nunique() <= 1])
# Out:
# Datentypen:
# adr_inter                        object
# adresse                          object
# adrzus_int                       object
# behindertenparkplatz             object
# bemerkung                        object
# ccmail                           object
# da                               object
# datum                            object
# datum_cms                        object
# dep                              object
# editor                           object
# erforderlichedokumente           object
# fax                              object
# hausnummer                       object
# hindernisfreiheit                object
# infrastruktur                    object
# isbetriebsferien_gebaeude        object
# isbetriebsferien_schalter        object
# kategorie                        object
# mail                             object
# name                             object
# namenzus                         object
# objectid                         object
# oeffnungszeiten_gebaeude_di      object
# oeffnungszeiten_gebaeude_do      object
# oeffnungszeiten_gebaeude_fr      object
# oeffnungszeiten_gebaeude_mi      object
# oeffnungszeiten_gebaeude_mo      object
# oeffnungszeiten_gebaeude_sa      object
# oeffnungszeiten_gebaeude_so      object
# oeffnungszeiten_schalter_di      object
# oeffnungszeiten_schalter_do      object
# oeffnungszeiten_schalter_fr      object
# oeffnungszeiten_schalter_mi      object
# oeffnungszeiten_schalter_mo      object
# oeffnungszeiten_schalter_sa      object
# oeffnungszeiten_schalter_so      object
# ort                              object
# plz                              object
# poi_id                           object
# postadresse                      object
# publish_internet                 object
# strasse                          object
# suchen                           object
# tel                              object
# tel2                             object
# www                              object
# zahlungsmittel_internet          object
# zahlungsmittel_schalter          object
# zahlungsmittel_telefon           object
# zvv_label                        object
# zvv_link                         object
# geometry                       geometry
# dtype: object
#
# Nullwerte pro Spalte:
# adr_inter                      20
# datum_cms                      20
# postadresse                    20
# tel2                           20
# hausnummer                     20
# fax                            20
# erforderlichedokumente         20
# strasse                        20
# ccmail                         20
# behindertenparkplatz           20
# adrzus_int                     20
# namenzus                       19
# bemerkung                       5
# oeffnungszeiten_schalter_mo     0
# oeffnungszeiten_schalter_sa     0
# oeffnungszeiten_schalter_mi     0
# ort                             0
# plz                             0
# poi_id                          0
# oeffnungszeiten_schalter_so     0
# www                             0
# publish_internet                0
# suchen                          0
# tel                             0
# oeffnungszeiten_schalter_do     0
# zahlungsmittel_internet         0
# zahlungsmittel_schalter         0
# zahlungsmittel_telefon          0
# zvv_label                       0
# zvv_link                        0
# oeffnungszeiten_schalter_fr     0
# oeffnungszeiten_gebaeude_mi     0
# oeffnungszeiten_schalter_di     0
# kategorie                       0
# da                              0
# datum                           0
# dep                             0
# editor                          0
# hindernisfreiheit               0
# infrastruktur                   0
# isbetriebsferien_gebaeude       0
# isbetriebsferien_schalter       0
# mail                            0
# oeffnungszeiten_gebaeude_so     0
# name                            0
# objectid                        0
# oeffnungszeiten_gebaeude_di     0
# oeffnungszeiten_gebaeude_do     0
# oeffnungszeiten_gebaeude_fr     0
# adresse                         0
# oeffnungszeiten_gebaeude_mo     0
# oeffnungszeiten_gebaeude_sa     0
# geometry                        0
# dtype: int64
#
#  Form: (20, 53)
#
#  Erste 5 Zeilen:
#   adr_inter                       adresse adrzus_int behindertenparkplatz  \
# 0      None         Mobiles WC Hürstwiese       None                 None
# 1      None         Mobiles WC Hohenstein       None                 None
# 2      None       Mobiles WC Kanzleiareal       None                 None
# 3      None  Mobiles Pissoir Piazza Cella       None                 None
# 4      None           Mobiles WC MFO Park       None                 None
#
#                                            bemerkung ccmail  \
# 0  Die mobile WC-Anlage ist jeweils von Anfang Ap...   None
# 1         Die mobile WC-Anlage ist ganzjährig offen.   None
# 2       Die mobile WC-Anlagen sind ganzjährig offen.   None
# 3                                               None   None
# 4  Die mobile WC-Anlage ist jeweils von Anfang Ap...   None
#
#                               da         datum datum_cms  \
# 0  Umwelt- und Gesundheitsschutz  202412161145      None
# 1  Umwelt- und Gesundheitsschutz  202412161145      None
# 2  Umwelt- und Gesundheitsschutz  202412161145      None
# 3  Umwelt- und Gesundheitsschutz  202412161145      None
# 4  Umwelt- und Gesundheitsschutz  202412161145      None
#
#                                         dep  ...               suchen  \
# 0  Gesundheits- und Umweltdepartement (GUD)  ...  Toilette, Toiletten
# 1  Gesundheits- und Umweltdepartement (GUD)  ...  Toilette, Toiletten
# 2  Gesundheits- und Umweltdepartement (GUD)  ...  Toilette, Toiletten
# 3  Gesundheits- und Umweltdepartement (GUD)  ...  Toilette, Toiletten
# 4  Gesundheits- und Umweltdepartement (GUD)  ...  Toilette, Toiletten
#
#                 tel  tel2                                   www  \
# 0  +41 44 412 43 65  None  https://www.stadt-zuerich.ch/zueriwc
# 1  +41 44 412 43 65  None  https://www.stadt-zuerich.ch/zueriwc
# 2  +41 44 412 43 65  None  https://www.stadt-zuerich.ch/zueriwc
# 3  +41 44 412 43 65  None  https://www.stadt-zuerich.ch/zueriwc
# 4  +41 44 412 43 65  None  https://www.stadt-zuerich.ch/zueriwc
#
#   zahlungsmittel_internet zahlungsmittel_schalter zahlungsmittel_telefon  \
# 0              NULL;NULL;              NULL;NULL;             NULL;NULL;
# 1              NULL;NULL;              NULL;NULL;             NULL;NULL;
# 2              NULL;NULL;              NULL;NULL;             NULL;NULL;
# 3              NULL;NULL;              NULL;NULL;             NULL;NULL;
# 4              NULL;NULL;              NULL;NULL;             NULL;NULL;
#
#                       zvv_label  \
# 0         Mobiles WC Hürstwiese
# 1         Mobiles WC Hohenstein
# 2       Mobiles WC Kanzleiareal
# 3  Mobiles Pissoir Piazza Cella
# 4           Mobiles WC MFO Park
#
#                                             zvv_link                  geometry
# 0  https://www.zvv.ch/de/fahrplan-und-information...   POINT (8.5199 47.41796)
# 1  https://www.zvv.ch/de/fahrplan-und-information...  POINT (8.48758 47.36086)
# 2  https://www.zvv.ch/de/fahrplan-und-information...  POINT (8.52521 47.37551)
# 3  https://www.zvv.ch/de/fahrplan-und-information...  POINT (8.52711 47.37838)
# 4  https://www.zvv.ch/de/fahrplan-und-information...   POINT (8.5397 47.41228)
#
# [5 rows x 53 columns]
#
#  Eindeutige Werte pro Spalte:
# geometry                       20
# poi_id                         20
# zvv_link                       20
# zvv_label                      20
# adresse                        20
# objectid                       20
# name                           20
# infrastruktur                  20
# plz                            12
# bemerkung                       7
# publish_internet                2
# www                             2
# editor                          2
# mail                            2
# tel                             1
# oeffnungszeiten_schalter_mo     1
# oeffnungszeiten_schalter_do     1
# oeffnungszeiten_schalter_fr     1
# oeffnungszeiten_schalter_mi     1
# zahlungsmittel_telefon          1
# oeffnungszeiten_schalter_sa     1
# zahlungsmittel_schalter         1
# oeffnungszeiten_schalter_so     1
# ort                             1
# zahlungsmittel_internet         1
# oeffnungszeiten_gebaeude_so     1
# suchen                          1
# oeffnungszeiten_schalter_di     1
# oeffnungszeiten_gebaeude_mi     1
# oeffnungszeiten_gebaeude_sa     1
# isbetriebsferien_schalter       1
# dep                             1
# da                              1
# oeffnungszeiten_gebaeude_mo     1
# hindernisfreiheit               1
# isbetriebsferien_gebaeude       1
# kategorie                       1
# namenzus                        1
# oeffnungszeiten_gebaeude_di     1
# oeffnungszeiten_gebaeude_do     1
# oeffnungszeiten_gebaeude_fr     1
# datum                           1
# datum_cms                       0
# adrzus_int                      0
# behindertenparkplatz            0
# ccmail                          0
# fax                             0
# tel2                            0
# erforderlichedokumente          0
# strasse                         0
# postadresse                     0
# hausnummer                      0
# adr_inter                       0
# dtype: int64
#
# ️ Doppelte Zeilen: 0
#  Doppelte Geometrien: 0
#
#  Spalten mit nur einem Wert:
# Index(['adr_inter', 'adrzus_int', 'behindertenparkplatz', 'ccmail', 'da',
#        'datum', 'datum_cms', 'dep', 'erforderlichedokumente', 'fax',
#        'hausnummer', 'hindernisfreiheit', 'isbetriebsferien_gebaeude',
#        'isbetriebsferien_schalter', 'kategorie', 'namenzus',
#        'oeffnungszeiten_gebaeude_di', 'oeffnungszeiten_gebaeude_do',
#        'oeffnungszeiten_gebaeude_fr', 'oeffnungszeiten_gebaeude_mi',
#        'oeffnungszeiten_gebaeude_mo', 'oeffnungszeiten_gebaeude_sa',
#        'oeffnungszeiten_gebaeude_so', 'oeffnungszeiten_schalter_di',
#        'oeffnungszeiten_schalter_do', 'oeffnungszeiten_schalter_fr',
#        'oeffnungszeiten_schalter_mi', 'oeffnungszeiten_schalter_mo',
#        'oeffnungszeiten_schalter_sa', 'oeffnungszeiten_schalter_so', 'ort',
#        'postadresse', 'strasse', 'suchen', 'tel', 'tel2',
#        'zahlungsmittel_internet', 'zahlungsmittel_schalter',
#        'zahlungsmittel_telefon'],
#       dtype='object')

# %% [markdown]
# ### 📝 Datenprüfung: Mobile WC-Anlagen Zürich (ZüriWC – mobil)
#
# Der Datensatz enthält **20 mobile öffentliche Toilettenanlagen** in der Stadt Zürich mit **53 Attributen** pro Eintrag. Alle Einträge enthalten gültige Geometriedaten in Form von Punktobjekten.
#
# **Datenstruktur:**
# - Alle Datentypen sind als `object` klassifiziert, außer der Spalte `geometry`.
# - 20 verschiedene `poi_id`, `adresse`, `zvv_label` etc. → keine Duplikate vorhanden.
#
# **Nullwerte:**
# - Mehrere Felder (z.B. `adr_inter`, `datum_cms`, `fax`, `hausnummer`) weisen durchgehend oder nahezu vollständig Nullwerte auf.
# - Diese Spalten liefern keinen Mehrwert für die Analyse und können entfernt werden.
#
# **Spalten mit nur einem (oder keinem) eindeutigen Wert:**
# - 39 Spalten haben nur eine Ausprägung oder sind leer (z.B. `zahlungsmittel_telefon`, `oeffnungszeiten_schalter_*`, `suchen`).
# - → Diese Spalten sind **nicht relevant** für analytische Fragestellungen.
#
# **Duplikate:**
# - Es sind **keine doppelten Zeilen oder Geometrien** vorhanden – die Datenqualität ist gut.
#
# **Inhaltliche Auffälligkeiten:**
# - Die Spalte `bemerkung` enthält teilweise hilfreiche Informationen zur saisonalen Verfügbarkeit der Anlagen (z.B. „von April bis Oktober geöffnet“) – dies kann für eine temporale Nutzungsanalyse verwendet werden.
# - Die Spalten `typ` und `kreis` fehlen im mobilen Datensatz. Eine spätere Ergänzung ist sinnvoll, wenn mobile WCs ebenfalls in die Versorgungsscore-Berechnung aufgenommen werden sollen.
#
# **Fazit:**
# Für die weitere Arbeit empfiehlt sich eine Reduktion des mobilen WC-Datensatzes auf die wichtigsten Spalten: Name, Adresse, Bemerkung, Infrastruktur, Öffnungszeiten (falls relevant) und Geometrie. Optional kann die `bemerkung`-Spalte analysiert werden, um **zeitliche Verfügbarkeit** (z.B. Sommerbetrieb) herauszufiltern. Die fehlende `typ`- und `kreis`-Zuordnung sollte später ergänzt werden (z.B. per Spatial Join mit Kreis-Shapefile).
